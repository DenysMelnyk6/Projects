# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time

# %%
def get_cars(url, starting_page=1, page_lim=5):
    global df_train
    rows = []
    for i in range(starting_page, page_lim+1):
        param = {'page':i}
        response = requests.get(url, param)
        cars = BeautifulSoup(response.text, 'html.parser')
        list_of_cars = cars.find_all('div',
                                     class_='ListingItemSequential-module__container')
        car_links = list(
            map(
                lambda x: x.find(
                    'div',
                    class_='ListingItemSequential-module__summaryLeft'
                ).a.get('href'), list_of_cars
            )
        )
    
        for link in car_links:
            time.sleep(0.4)
            response = requests.get(link)
            response.encoding = 'utf-8'
            car = BeautifulSoup(response.text, 'html.parser')
            table = car.find(class_='CardInfo')
            try:
                model_link = car.find('a', class_='CardCatalogLink').get('href')
                specific_car = {'year':[table.find('li', class_='CardInfoRow_year').a.text],
                                'mileage':[table.find('li', class_='CardInfoRow_kmAge').text],
                                'body':[table.find('li', class_='CardInfoRow_bodytype').a.text],
                                'colour':[table.find('li', class_='CardInfoRow_color').a.text],
                                'engine':[table.find('li', class_='CardInfoRow_engine').find('div').text],
                                'transmission':[table.find('li', class_='CardInfoRow_transmission').text],
                                'drive_unit':[table.find('li', class_='CardInfoRow_drive').text],
                                'wheel':[table.find('li', class_='CardInfoRow_wheel').text],
                                'condition':[table.find('li', class_='CardInfoRow_state').text],
                                'owners':[table.find('li', class_='CardInfoRow_ownersCount').text],
                                'vehicle_licence':[table.find('li', class_='CardInfoRow_pts').text],
                                'customs':[table.find('li', class_='CardInfoRow CardInfoRow_customs').text]}
                model = requests.get(model_link)
                model.encoding = 'utf-8'
                model_info = BeautifulSoup(model.text, 'html.parser')
                tables = model_info.find_all('dl', class_='list-values')
                for listed in tables:
                    time.sleep(0.1)
                    k = len(listed.find_all('dt'))
                    for i in range(0, k):
                        name = listed.find_all('dt')[i].text
                        value = listed.find_all('dd')[i].text
                        specific_car[name] = value
                
                
                
                
                
            except:
                continue
            if str(type(table.find('li', class_='CardInfoRow_owningTime'))) == "<class 'bs4.element.Tag'>":
                specific_car['owned_for'] = table.find('li', class_='CardInfoRow_owningTime').text
            else:
                specific_car['owned_for'] = None
            df = pd.DataFrame.from_dict(specific_car)
            rows.append(df)
    df_train = pd.concat(rows)
    return df_train

# %%
response = requests.get('https://auto.ru/cars/used/sale/bmw/7er/1103634891-900491ab/')
response.encoding = 'utf-8'
car = BeautifulSoup(response.text, 'html.parser')
table = car.find(class_='CardInfo')
specific_car = {'year':[table.find('li', class_='CardInfoRow_year').a.text],
                                'travelled':[table.find('li', class_='CardInfoRow_kmAge').text],
                                'body':[table.find('li', class_='CardInfoRow_bodytype').a.text],
                                'colour':[table.find('li', class_='CardInfoRow_color').a.text],
                                'engine':[table.find('li', class_='CardInfoRow_engine').find('div').text],
                                'transmission':[table.find('li', class_='CardInfoRow_transmission').text],
                                'drive_unit':[table.find('li', class_='CardInfoRow_drive').text],
                                'wheel':[table.find('li', class_='CardInfoRow_wheel').text],
                                'condition':[table.find('li', class_='CardInfoRow_state').text],
                                'owners':[table.find('li', class_='CardInfoRow_ownersCount').text],
                                'vehicle_licence':[table.find('li', class_='CardInfoRow_pts').text],
                                'customs':[table.find('li', class_='CardInfoRow CardInfoRow_customs').text]}

# %%
model_link = car.find('a', class_='CardCatalogLink').get('href')
model = requests.get(model_link)
model.encoding = 'utf-8'
car_model = BeautifulSoup(model.text, 'html.parser')

# %%
model = requests.get(model_link)
model.encoding = 'utf-8'
model_info = BeautifulSoup(model.text, 'html.parser')
tables = model_info.find_all('dl', class_='list-values')
for listed in tables:
    k = len(uwu.find_all('dt'))
    for i in range(0, k):
        name = listed.find_all('dt')[i].text
        value = listed.find_all('dd')[i].text
        specific_car[name] = value
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-1222f7ecaa84> in <module>
#       6     k = len(uwu.find_all('dt'))
#       7     for i in range(0, k):
# ----> 8         name = listed.find_all('dt')[i].text
#       9         value = listed.find_all('dd')[i].text
#      10         specific_car[name] = value
#
# IndexError: list index out of range

# %%
specific_car

# %%
df_train = get_cars('https://auto.ru/cars/used/?year_to=2020&output_type=table', 1, 1)
# Out:
# [   year         travelled  body colour                     engine  \
# 0  2009  Пробег170 000 км  купе  серый  1.8 л / 143 л.с. / Бензин
#
#             transmission    drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводзадний  РульЛевый
#
#                      condition                owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы3 или более  ...  компрессор
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         143 / 105 при 4200
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          220 при 2500 – 4200                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)            9.3
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           82 × 85      None
#
# [1 rows x 59 columns],    year        travelled               body colour                     engine  \
# 0  2019  Пробег10 200 км  внедорожник 5 дв.  белый  4.0 л / 249 л.с. / Бензин
#
#             transmission    drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводполный  РульЛевый
#
#                      condition               owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         249 / 183 при 5600
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 381 при 4400             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    6                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)           10.4
#
#   Диаметр цилиндра и ход поршня, мм                  owned_for
# 0                           94 × 95  Владение1 год и 9 месяцев
#
# [1 rows x 59 columns],    year         travelled   body   colour                     engine  \
# 0  2002  Пробег290 000 км  седан  голубой  2.3 л / 131 л.с. / Бензин
#
#           transmission    drive_unit      wheel                    condition  \
# 0  Коробкамеханическая  Приводзадний  РульЛевый  СостояниеНе требует ремонта
#
#                  owners  ... Тип наддува  \
# 0  Владельцы2 владельца  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                          131 / 96 при 5200
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 188 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)            9.3
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           92 × 86      None
#
# [1 rows x 60 columns],    year        travelled               body colour                     engine  \
# 0  2019  Пробег43 000 км  внедорожник 5 дв.  белый  1.5 л / 109 л.с. / Дизель
#
#           transmission    drive_unit      wheel                    condition  \
# 0  Коробкамеханическая  Приводполный  РульЛевый  СостояниеНе требует ремонта
#
#                 owners  ... Объем двигателя, см³  Тип наддува  \
# 0  Владельцы1 владелец  ...                 1461  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                          109 / 80 при 4000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 240 при 1750                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр Степень сжатия  \
# 0                    4                         2           15.2
#
#   Диаметр цилиндра и ход поршня, мм                  owned_for
# 0                         76 × 80.5  Владение1 год и 6 месяцев
#
# [1 rows x 60 columns],    year        travelled               body  colour  \
# 0  2019  Пробег40 100 км  внедорожник 5 дв.  жёлтый
#
#                       engine           transmission    drive_unit      wheel  \
# 0  4.0 л / 650 л.с. / Бензин  Коробкаавтоматическая  Приводполный  РульЛевый
#
#                      condition               owners  ... Объем двигателя, см³  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...                 3996
#
#    Тип наддува Максимальная мощность, л.с./кВт при об/мин  \
# 0  турбонаддув                         650 / 478 при 6000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          850 при 2250 – 4500             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    8                         4
#
#           Система питания двигателя Диаметр цилиндра и ход поршня, мм  \
# 0  непосредственный впрыск (прямой)                                 -
#
#         owned_for
# 0  Владение2 года
#
# [1 rows x 58 columns],    year        travelled   body  colour                     engine  \
# 0  2019  Пробег16 947 км  седан  чёрный  2.5 л / 180 л.с. / Бензин
#
#             transmission      drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводпередний  РульЛевый
#
#                      condition               owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         180 / 132 при 6000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 232 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)           10.5
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                      88.5 × 101.5      None
#
# [1 rows x 61 columns],    year        travelled   body colour                     engine  \
# 0  2019  Пробег25 883 км  седан  серый  2.5 л / 180 л.с. / Бензин
#
#             transmission      drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводпередний  РульЛевый
#
#                      condition               owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         180 / 132 при 6000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 232 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)           10.5
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                      88.5 × 101.5      None
#
# [1 rows x 61 columns],    year        travelled               body      colour  \
# 0  2018  Пробег32 919 км  внедорожник 3 дв.  коричневый
#
#                      engine         transmission    drive_unit      wheel  \
# 0  1.7 л / 83 л.с. / Бензин  Коробкамеханическая  Приводполный  РульЛевый
#
#                      condition                owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы3 или более  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                           83 / 61 при 5000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 129 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         2
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)            9.3
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           82 × 80      None
#
# [1 rows x 60 columns],    year        travelled  body colour                     engine  \
# 0  2016  Пробег39 000 км  купе  серый  4.0 л / 510 л.с. / Бензин
#
#             transmission    drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводзадний  РульЛевый
#
#                      condition                owners  ...  Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы3 или более  ...  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                  510 / 375 при 5500 – 6250
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          700 при 1750 – 4500             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    8                         4
#
#           Система питания двигателя Степень сжатия  \
# 0  непосредственный впрыск (прямой)           10.5
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           83 × 92      None
#
# [1 rows x 59 columns],    year        travelled               body       colour  \
# 0  2016  Пробег48 791 км  внедорожник 5 дв.  серебристый
#
#                       engine         transmission      drive_unit      wheel  \
# 0  1.6 л / 114 л.с. / Бензин  Коробкамеханическая  Приводпередний  РульЛевый
#
#                      condition               owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                          114 / 84 при 5500
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 156 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)           10.7
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                         78 × 83.6      None
#
# [1 rows x 61 columns],    year        travelled               body colour                    engine  \
# 0  2018  Пробег50 852 км  внедорожник 3 дв.  синий  1.7 л / 83 л.с. / Бензин
#
#           transmission    drive_unit      wheel                    condition  \
# 0  Коробкамеханическая  Приводполный  РульЛевый  СостояниеНе требует ремонта
#
#                 owners  ... Тип наддува  \
# 0  Владельцы1 владелец  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                           83 / 61 при 5000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 129 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         2
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)            9.3
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           82 × 80      None
#
# [1 rows x 60 columns],    year        travelled               body colour                     engine  \
# 0  2019  Пробег10 000 км  внедорожник 5 дв.  белый  2.0 л / 190 л.с. / Дизель
#
#             transmission    drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводполный  РульЛевый
#
#                      condition               owners  ... Объем двигателя, см³  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...                 1995
#
#    Тип наддува Максимальная мощность, л.с./кВт при об/мин  \
# 0  турбонаддув                         190 / 140 при 4000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          400 при 1750 – 2500                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр Степень сжатия  \
# 0                    4                         4           16.5
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           84 × 90      None
#
# [1 rows x 62 columns],    year        travelled  body colour                     engine  \
# 0  2017  Пробег35 000 км  купе  серый  5.7 л / 380 л.с. / Бензин
#
#             transmission    drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводзадний  РульЛевый
#
#                      condition               owners  ... Марка топлива  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...         АИ-95
#
#   Расположение двигателя Объем двигателя, см³  \
# 0   переднее, продольное                 5654
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         380 / 279 при 5150
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 555 при 4300             V-образное
#
#   Количество цилиндров         Система питания двигателя  \
# 0                    8  непосредственный впрыск (прямой)
#
#   Диаметр цилиндра и ход поршня, мм          owned_for
# 0                                 -  Владение6 месяцев
#
# [1 rows x 56 columns],    year        travelled   body colour                     engine  \
# 0  2016  Пробег50 000 км  седан  синий  3.0 л / 431 л.с. / Бензин
#
#               transmission    drive_unit      wheel  \
# 0  Коробкароботизированная  Приводзадний  РульЛевый
#
#                      condition                owners  ...  Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы2 владельца  ...  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                  431 / 317 при 5500 – 7300
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          550 при 1850 – 5500                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    6                         4
#
#           Система питания двигателя Степень сжатия  \
# 0  непосредственный впрыск (прямой)           10.2
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                         84 × 89.6      None
#
# [1 rows x 61 columns],    year        travelled  body   colour                     engine  \
# 0  2014  Пробег79 218 км  купе  красный  3.8 л / 540 л.с. / Бензин
#
#               transmission    drive_unit      wheel  \
# 0  Коробкароботизированная  Приводполный  РульЛевый
#
#                      condition                owners  ...  Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы3 или более  ...  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         540 / 397 при 6400
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          628 при 3200 – 5800             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    6                         4
#
#           Система питания двигателя Степень сжатия  \
# 0  непосредственный впрыск (прямой)              9
#
#   Диаметр цилиндра и ход поршня, мм                  owned_for
# 0                       95.5 × 88.4  Владение2 года и 2 месяца
#
# [1 rows x 61 columns],    year        travelled             body  colour                     engine  \
# 0  2019  Пробег30 000 км  универсал 5 дв.  чёрный  1.6 л / 113 л.с. / Бензин
#
#       transmission      drive_unit      wheel                    condition  \
# 0  Коробкавариатор  Приводпередний  РульЛевый  СостояниеНе требует ремонта
#
#                  owners  ... Тип наддува  \
# 0  Владельцы2 владельца  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                          113 / 83 при 5500
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 152 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)           10.7
#
#   Диаметр цилиндра и ход поршня, мм         owned_for
# 0                         78 × 83.5  Владение4 месяца
#
# [1 rows x 59 columns],    year        travelled               body  colour  \
# 0  2018  Пробег53 202 км  внедорожник 5 дв.  чёрный
#
#                       engine           transmission    drive_unit      wheel  \
# 0  4.0 л / 585 л.с. / Бензин  Коробкаавтоматическая  Приводполный  РульЛевый
#
#                      condition               owners  ...  Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         585 / 430 при 6000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          850 при 2500 – 3500             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    8                         4
#
#           Система питания двигателя Степень сжатия  \
# 0  непосредственный впрыск (прямой)           10.5
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           83 × 92      None
#
# [1 rows x 61 columns],    year         travelled   body  colour                     engine  \
# 0  2013  Пробег123 200 км  седан  чёрный  1.4 л / 107 л.с. / Бензин
#
#           transmission      drive_unit      wheel  \
# 0  Коробкамеханическая  Приводпередний  РульЛевый
#
#                      condition                owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы3 или более  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                          107 / 79 при 6300
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 135 при 5000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)           10.5
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                         77 × 74.9      None
#
# [1 rows x 60 columns],    year         travelled               body  colour  \
# 0  2007  Пробег136 130 км  внедорожник 5 дв.  чёрный
#
#                       engine           transmission    drive_unit      wheel  \
# 0  2.5 л / 174 л.с. / Дизель  Коробкаавтоматическая  Приводполный  РульЛевый
#
#                      condition                owners  ...  \
# 0  СостояниеНе требует ремонта  Владельцы2 владельца  ...
#
#   Объем двигателя, см³  Тип наддува  \
# 0                 2488  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         174 / 128 при 4000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 403 при 2000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр Степень сжатия  \
# 0                    4                         4           16.5
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                          89 × 100      None
#
# [1 rows x 58 columns],    year         travelled   body      colour                     engine  \
# 0  2010  Пробег146 255 км  седан  фиолетовый  2.5 л / 182 л.с. / Бензин
#
#       transmission      drive_unit      wheel                    condition  \
# 0  Коробкавариатор  Приводпередний  РульЛевый  СостояниеНе требует ремонта
#
#                  owners  ... Тип наддува  \
# 0  Владельцы2 владельца  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         182 / 134 при 6000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 228 при 4400             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    6                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)            9.8
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                         85 × 73.3      None
#
# [1 rows x 59 columns],    year         travelled               body colour  \
# 0  2015  Пробег142 707 км  внедорожник 5 дв.  белый
#
#                       engine         transmission    drive_unit      wheel  \
# 0  1.6 л / 114 л.с. / Бензин  Коробкамеханическая  Приводполный  РульЛевый
#
#                      condition               owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                          114 / 84 при 5500
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 156 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)           10.7
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                         78 × 83.6      None
#
# [1 rows x 61 columns],    year        travelled               body colour                     engine  \
# 0  2019  Пробег55 000 км  внедорожник 5 дв.  серый  3.0 л / 340 л.с. / Бензин
#
#             transmission    drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводполный  РульЛевый
#
#                      condition               owners  ...  Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                  340 / 250 при 5000 – 6400
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          500 при 1370 – 4500             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    6                         4
#
#           Система питания двигателя Степень сжатия  \
# 0  непосредственный впрыск (прямой)           11.2
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                         84.5 × 89      None
#
# [1 rows x 61 columns],    year        travelled   body  colour                     engine  \
# 0  2016  Пробег82 287 км  седан  чёрный  2.0 л / 184 л.с. / Бензин
#
#             transmission    drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводзадний  РульЛевый
#
#                      condition                owners  ...  Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы3 или более  ...  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         184 / 135 при 5500
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          300 при 1200 – 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#           Система питания двигателя Степень сжатия  \
# 0  непосредственный впрыск (прямой)            9.8
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           83 × 92      None
#
# [1 rows x 63 columns],    year        travelled               body colour                     engine  \
# 0  2018  Пробег27 000 км  внедорожник 5 дв.  белый  1.6 л / 114 л.с. / Бензин
#
#           transmission    drive_unit      wheel                    condition  \
# 0  Коробкамеханическая  Приводполный  РульЛевый  СостояниеНе требует ремонта
#
#                 owners  ... Тип наддува  \
# 0  Владельцы1 владелец  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                          114 / 84 при 5500
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 156 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)           10.7
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                         78 × 83.6      None
#
# [1 rows x 61 columns],    year        travelled               body colour                     engine  \
# 0  2019  Пробег90 388 км  внедорожник 5 дв.  синий  3.0 л / 340 л.с. / Бензин
#
#             transmission    drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводполный  РульЛевый
#
#                      condition               owners  ...  Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                  340 / 250 при 5300 – 6400
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          450 при 1340 – 5300             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    6                         4
#
#           Система питания двигателя Степень сжатия  \
# 0  непосредственный впрыск (прямой)           11.2
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                         84.5 × 89      None
#
# [1 rows x 59 columns],    year        travelled               body colour                     engine  \
# 0  2018  Пробег37 144 км  внедорожник 5 дв.  серый  2.2 л / 200 л.с. / Дизель
#
#             transmission    drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводполный  РульЛевый
#
#                      condition                owners  ...  \
# 0  СостояниеНе требует ремонта  Владельцы3 или более  ...
#
#   Объем двигателя, см³  Тип наддува  \
# 0                 2199  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         200 / 147 при 3800
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          441 при 1750 – 2750                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр Степень сжатия  \
# 0                    4                         4             16
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                         85.4 × 96      None
#
# [1 rows x 59 columns],    year         travelled   body  colour                     engine  \
# 0  2004  Пробег303 303 км  седан  чёрный  2.3 л / 131 л.с. / Бензин
#
#           transmission    drive_unit      wheel                    condition  \
# 0  Коробкамеханическая  Приводзадний  РульЛевый  СостояниеНе требует ремонта
#
#                  owners  ... Тип наддува  \
# 0  Владельцы3 или более  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                          131 / 96 при 5200
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 188 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)            9.3
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           92 × 86      None
#
# [1 rows x 58 columns],    year         travelled   body   colour                    engine  \
# 0  1998  Пробег112 000 км  седан  красный  1.5 л / 72 л.с. / Бензин
#
#           transmission    drive_unit      wheel                    condition  \
# 0  Коробкамеханическая  Приводзадний  РульЛевый  СостояниеНе требует ремонта
#
#                  owners  ... Тип наддува  \
# 0  Владельцы3 или более  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                           72 / 53 при 5000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 105 при 3500                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр Система питания двигателя  \
# 0                    4                         2                карбюратор
#
#   Степень сжатия Диаметр цилиндра и ход поршня, мм owned_for
# 0            8.5                           76 × 80      None
#
# [1 rows x 61 columns],    year        travelled               body  colour  \
# 0  2019  Пробег24 822 км  внедорожник 5 дв.  чёрный
#
#                       engine           transmission    drive_unit      wheel  \
# 0  3.6 л / 318 л.с. / Бензин  Коробкаавтоматическая  Приводполный  РульЛевый
#
#                      condition               owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         318 / 234 при 6800
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 360 при 5500             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    6                         4
#
#           Система питания двигателя Степень сжатия  \
# 0  непосредственный впрыск (прямой)           11.5
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                         95 × 85.8      None
#
# [1 rows x 60 columns],    year         travelled           body  colour                     engine  \
# 0  2013  Пробег135 000 км  хэтчбек 5 дв.  чёрный  2.0 л / 180 л.с. / Бензин
#
#             transmission      drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводпередний  РульЛевый
#
#                      condition                owners  ...  Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы3 или более  ...  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         180 / 132 при 5000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                          300 при 2700 – 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    5                         4
#
#           Система питания двигателя Степень сжатия  \
# 0  непосредственный впрыск (прямой)           10.5
#
#   Диаметр цилиндра и ход поршня, мм                owned_for
# 0                           81 × 77  Владение1 год и 1 месяц
#
# [1 rows x 61 columns],    year        travelled  body   colour                     engine  \
# 0  2018  Пробег52 000 км  купе  красный  3.6 л / 309 л.с. / Бензин
#
#             transmission    drive_unit      wheel  \
# 0  Коробкаавтоматическая  Приводзадний  РульЛевый
#
#                      condition               owners  ...  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...
#
#   Расположение двигателя Объем двигателя, см³  \
# 0   переднее, продольное                 3604
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         309 / 227 при 6350
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 363 при 4800             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    6                         4
#
#           Система питания двигателя Диаметр цилиндра и ход поршня, мм  \
# 0  непосредственный впрыск (прямой)                                 -
#
#                      owned_for
# 0  Владение2 года и 10 месяцев
#
# [1 rows x 57 columns],    year       travelled             body   colour                     engine  \
# 0  2019  Пробег5 100 км  универсал 5 дв.  красный  1.8 л / 122 л.с. / Бензин
#
#           transmission      drive_unit      wheel  \
# 0  Коробкамеханическая  Приводпередний  РульЛевый
#
#                      condition                owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы2 владельца  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                          122 / 90 при 5900
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 170 при 3700                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)           10.5
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           82 × 84      None
#
# [1 rows x 60 columns],    year        travelled     body  colour                     engine  \
# 0  2018  Пробег78 000 км  минивэн  чёрный  1.6 л / 160 л.с. / Дизель
#
#               transmission      drive_unit      wheel  \
# 0  Коробкароботизированная  Приводпередний  РульЛевый
#
#                      condition               owners  ...  \
# 0  СостояниеНе требует ремонта  Владельцы1 владелец  ...
#
#   Расположение двигателя Объем двигателя, см³  Тип наддува  \
# 0   переднее, поперечное                 1598  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         160 / 118 при 4000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 380 при 1750                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#   Диаметр цилиндра и ход поршня, мм        owned_for
# 0                         76 × 80.5  Владение1 месяц
#
# [1 rows x 61 columns],    year       travelled               body colour                    engine  \
# 0  2020  Пробег4 357 км  внедорожник 3 дв.  серый  1.7 л / 83 л.с. / Бензин
#
#           transmission    drive_unit      wheel                    condition  \
# 0  Коробкамеханическая  Приводполный  РульЛевый  СостояниеНе требует ремонта
#
#                 owners  ... Тип наддува  \
# 0  Владельцы1 владелец  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                           83 / 61 при 5000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 129 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         2
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)            9.3
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           82 × 80      None
#
# [1 rows x 60 columns],    year         travelled   body colour                     engine  \
# 0  2016  Пробег139 000 км  седан  белый  1.4 л / 107 л.с. / Бензин
#
#           transmission      drive_unit      wheel  \
# 0  Коробкамеханическая  Приводпередний  РульЛевый
#
#                      condition                owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы2 владельца  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                          107 / 79 при 6300
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 135 при 5000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         4
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)           10.5
#
#   Диаметр цилиндра и ход поршня, мм                  owned_for
# 0                         77 × 74.9  Владение3 года и 2 месяца
#
# [1 rows x 61 columns],    year        travelled               body colour                    engine  \
# 0  2017  Пробег81 340 км  внедорожник 3 дв.  синий  1.7 л / 83 л.с. / Бензин
#
#           transmission    drive_unit      wheel                    condition  \
# 0  Коробкамеханическая  Приводполный  РульЛевый  СостояниеНе требует ремонта
#
#                 owners  ... Тип наддува  \
# 0  Владельцы1 владелец  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                           83 / 60 при 5000
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 128 при 4000                 рядное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    4                         2
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)            9.3
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                           82 × 80      None
#
# [1 rows x 62 columns],    year        travelled               body  colour  \
# 0  2019  Пробег32 922 км  внедорожник 5 дв.  чёрный
#
#                       engine           transmission    drive_unit      wheel  \
# 0  6.2 л / 426 л.с. / Бензин  Коробкаавтоматическая  Приводполный  РульЛевый
#
#                      condition                owners  ... Тип наддува  \
# 0  СостояниеНе требует ремонта  Владельцы2 владельца  ...         нет
#
#   Максимальная мощность, л.с./кВт при об/мин  \
# 0                         426 / 313 при 5600
#
#   Максимальный крутящий момент, Н*м при об/мин Расположение цилиндров  \
# 0                                 621 при 4100             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр  \
# 0                    8                         2
#
#                Система питания двигателя Степень сжатия  \
# 0  распределенный впрыск (многоточечный)           11.5
#
#   Диаметр цилиндра и ход поршня, мм owned_for
# 0                       103.25 × 92      None
#
# [1 rows x 60 columns]]

# %%
df_train = df_train.drop([]
                         axis=1)

# %%
df_train.columns
# Out:
# Index(['year', 'travelled', 'body', 'colour', 'engine', 'transmission',
#        'drive_unit', 'wheel', 'condition', 'owners', 'vehicle_licence',
#        'customs', 'Объем', 'Мощность', 'Коробка', 'Тип двигателя', 'Топливо',
#        'Привод', 'Разгон', 'Расход', 'Страна марки', 'Класс автомобиля',
#        'Количество дверей', 'Количество мест', 'Длина', 'Ширина', 'Высота',
#        'Колёсная база', 'Клиренс', 'Ширина передней колеи',
#        'Ширина задней колеи', 'Размер колёс', 'Объем багажника мин/макс, л',
#        'Объём топливного бака, л', 'Снаряженная масса, кг', 'Полная масса, кг',
#        'Коробка передач', 'Количество передач', 'Тип привода',
#        'Тип передней подвески', 'Тип задней подвески', 'Передние тормоза',
#        'Задние тормоза', 'Максимальная скорость, км/ч',
#        'Разгон до 100 км/ч, с', 'Расход топлива, л город/трасса/смешанный',
#        'Марка топлива', 'Расположение двигателя', 'Объем двигателя, см³',
#        'Тип наддува', 'Максимальная мощность, л.с./кВт при об/мин',
#        'Максимальный крутящий момент, Н*м при об/мин',
#        'Расположение цилиндров', 'Количество цилиндров',
#        'Число клапанов на цилиндр', 'Система питания двигателя',
#        'Степень сжатия', 'Диаметр цилиндра и ход поршня, мм', 'owned_for',
#        'Экологический класс', 'Выбросы CO2, г/км', 'Оценка безопасности',
#        'Название рейтинга', 'Расход топлива, л город',
#        'Расход топлива, л смешанный', 'Расход топлива, л город/трасса'],
#       dtype='object')

# %%
df_train.head()
# Out:
#    year         travelled               body       colour  \
# 0  2007  Пробег155 000 км  внедорожник 5 дв.        серый
# 0  2007  Пробег125 000 км              седан  серебристый
# 0  2017   Пробег60 000 км              седан        белый
# 0  2019   Пробег43 000 км  внедорожник 5 дв.        белый
# 0  2019   Пробег40 100 км  внедорожник 5 дв.       жёлтый
#
#                       engine           transmission      drive_unit  \
# 0  4.8 л / 355 л.с. / Бензин  Коробкаавтоматическая    Приводполный
# 0  1.6 л / 101 л.с. / Бензин  Коробкаавтоматическая  Приводпередний
# 0  3.0 л / 265 л.с. / Дизель  Коробкаавтоматическая    Приводполный
# 0  1.5 л / 109 л.с. / Дизель    Коробкамеханическая    Приводполный
# 0  4.0 л / 650 л.с. / Бензин  Коробкаавтоматическая    Приводполный
#
#        wheel                    condition                owners  ...  \
# 0  РульЛевый  СостояниеНе требует ремонта  Владельцы3 или более  ...
# 0  РульЛевый  СостояниеНе требует ремонта   Владельцы1 владелец  ...
# 0  РульЛевый  СостояниеНе требует ремонта  Владельцы2 владельца  ...
# 0  РульЛевый  СостояниеНе требует ремонта   Владельцы1 владелец  ...
# 0  РульЛевый  СостояниеНе требует ремонта   Владельцы1 владелец  ...
#
#   Расположение двигателя Объем двигателя, см³  Тип наддува  \
# 0   переднее, продольное                 4799          нет
# 0   переднее, поперечное                 1591          нет
# 0   переднее, продольное                 2993  турбонаддув
# 0   переднее, поперечное                 1461  турбонаддув
# 0   переднее, продольное                 3996  турбонаддув
#
#   Максимальная мощность, л.с./кВт при об/мин Расположение цилиндров  \
# 0                         355 / 261 при 6300             V-образное
# 0                          101 / 74 при 5500                 рядное
# 0                         265 / 195 при 4000                 рядное
# 0                          109 / 80 при 4000                 рядное
# 0                         650 / 478 при 6000             V-образное
#
#   Количество цилиндров Число клапанов на цилиндр Степень сжатия  \
# 0                    8                         4             11
# 0                    4                         4            9.5
# 0                    6                         4           16.5
# 0                    4                         2           15.2
# 0                    8                         4            NaN
#
#   Диаметр цилиндра и ход поршня, мм                    owned_for
# 0                         93 × 88.3  Владение3 года и 11 месяцев
# 0                         78 × 83.4                         None
# 0                           84 × 90                         None
# 0                         76 × 80.5    Владение1 год и 6 месяцев
# 0                                 -               Владение2 года
#
# [5 rows x 52 columns]

# %%
display(df_train.iloc[0])
# Out:
# year                                                   1996
# travelled                                  Пробег400 000 км
# body                                      внедорожник 5 дв.
# colour                                               чёрный
# engine                            4.2 л / 116 л.с. / Дизель
#                                             ...
# Оценка безопасности                                     NaN
# Название рейтинга                                       NaN
# Экологический класс                                     NaN
# Расход топлива, л смешанный                             NaN
# Расход топлива, л город/трасса                          NaN
# Name: 0, Length: 65, dtype: object

# %%
df_train = df_train.reset_index().drop('index', axis = 1)

# %%
df_train['travelled'] = df_train.travelled.apply(lambda x:x.replace('Пробег', ''))
df_train['travelled'] = df_train.travelled.apply(lambda x:x.replace('км', ''))
df_train['travelled'] = df_train.travelled.apply(lambda x:int(x.replace(u'\xa0', '')))

# %%
df_train['engine'] = df_train.engine.apply(lambda x: x.split('/'))
df_train['engine_displacement'] = df_train.engine.apply(lambda x: float(x[0].replace(' л', '')))
df_train['engine_power'] = df_train.engine.apply(lambda x: int(x[1].replace(u'\xa0л.с.', '')))
df_train['fuel_type'] = df_train.engine.apply(lambda x: x[2])
df_train = df_train.drop('engine', axis=1)

# %%
df_train.transmission = df_train.transmission.apply(lambda x: x.replace('Коробка',''))
df_train.wheel = df_train.wheel.apply(lambda x: x.replace('Руль',''))
df_train.condition = df_train.condition.apply(lambda x: x.replace('Состояние',''))
df_train.owners = df_train.owners.apply(lambda x: x.replace('Владельцы',''))
df_train.vehicle_licence = df_train.vehicle_licence.apply(lambda x: x.replace('ПТС',''))
df_train.customs = df_train.customs.apply(lambda x: x.replace('Таможня',''))
df_train.drive_unit = df_train.drive_unit.apply(lambda x: x.replace('Привод',''))

# %%
not_empty = df_train.loc[(df_train.owned_for.isna()==False)].index
df_train.loc[not_empty, 'owned_for'] = df_train.iloc[not_empty].owned_for.apply((lambda x: x.replace('Владение','')))

# %%
df_train.head()
# Out:
#    year  travelled               body      colour      transmission  \
# 0  2019      31000  внедорожник 5 дв.       синий    автоматическая
# 1  2019       7700              седан  коричневый      механическая
# 2  2019       8000  внедорожник 5 дв.       серый    автоматическая
# 3  2013      17000               купе     красный  роботизированная
# 4  2015     154469              седан      чёрный    автоматическая
#
#   drive_unit  wheel           condition       owners vehicle_licence  \
# 0     полный  Левый  Не требует ремонта   1 владелец        Оригинал
# 1   передний  Левый  Не требует ремонта   1 владелец        Оригинал
# 2   передний  Левый  Не требует ремонта  2 владельца        Дубликат
# 3     полный  Левый  Не требует ремонта  3 или более        Оригинал
# 4     полный  Левый  Не требует ремонта  3 или более        Дубликат
#
#       customs          owned_for  engine_displacement  engine_power fuel_type
# 0  Растаможен  1 год и 8 месяцев                  2.0           238    Бензин
# 1  Растаможен               None                  1.6            87    Бензин
# 2  Растаможен          5 месяцев                  2.0           150    Бензин
# 3  Растаможен               None                  6.5           700    Бензин
# 4  Растаможен               None                  2.0           276    Бензин

# %%
df_train.to_csv('train.csv', index=True)
